# %% [markdown]
# # Analisis inicial de dataset

# %%
import os, shutil

baseDir = './images'
i=0
l=0
minSize=1000
maxSize=0

for x in os.listdir(baseDir):
    subDir = baseDir + "/" + x
    size = os.listdir(subDir)
    i=i+1
    l = len(size)
    if l < minSize:
        minSize = l
    if l > maxSize:
        maxSize = l
        
print("maxSize ", maxSize)
print("minSize ", minSize)
# Out:
# maxSize  252
# minSize  148

# %% [markdown]
# # Preparando los datos

# %%
# Directorio de trabajo
processDir = './process'
os.makedirs(processDir, exist_ok=True)

# Directorios para entrenamiento, test y validacion
train_dir = os.path.join(processDir, 'train')
os.makedirs(train_dir, exist_ok=True)

validation_dir = os.path.join(processDir, 'validation')
os.makedirs(validation_dir, exist_ok=True)

test_dir = os.path.join(processDir, 'test')
os.makedirs(test_dir, exist_ok=True)

# %%
#Porcentajes para el split de datos
porTest = 15
porVal = 15

for clase in os.listdir(baseDir):
    subDir = baseDir + "/" + clase
    files = os.listdir(subDir)
    
    # Crea el directorio en test
    categ_test_dir = os.path.join(test_dir, clase)
    os.makedirs(categ_test_dir, exist_ok=True)
    
    cantTest = (len(files) * porTest) // 100
    
    # Copiamos las imagenes test
    fnames = files[0:cantTest]
    for fname in fnames:
        src = os.path.join(subDir, fname)
        dst = os.path.join(categ_test_dir, fname)
        shutil.copyfile(src, dst)

    # Crea el directorio en validacion
    categ_val_dir = os.path.join(validation_dir, clase)
    os.makedirs(categ_val_dir, exist_ok=True)
    
    cantVal = (len(files) * porVal) // 100

    # Copiamos las imagenes validacion
    fnames = files[cantTest: (cantTest + cantVal)]
    for fname in fnames:
        src = os.path.join(subDir, fname)
        dst = os.path.join(categ_val_dir, fname)
        shutil.copyfile(src, dst)

    # Crea el directorio en train
    categ_train_dir = os.path.join(train_dir, clase)
    os.makedirs(categ_train_dir, exist_ok=True)

    cantTrain = len(files) - (cantTest + cantVal)

    # Copiamos las imagenes train
    fnames = files[(cantTest + cantVal): len(files)]
    for fname in fnames:
        src = os.path.join(subDir, fname)
        dst = os.path.join(categ_train_dir, fname)
        shutil.copyfile(src, dst)
    
    print("dir ", subDir, len(files))
    print("categ_test_dir  ", categ_test_dir,cantTest)
    print("categ_val_dir   ", categ_val_dir, cantVal)
    print("categ_train_dir ", categ_train_dir , cantTrain)
# Out:
# dir  ./images/n02085620-Chihuahua 152
# categ_test_dir   ./process\test\n02085620-Chihuahua 22
# categ_val_dir    ./process\validation\n02085620-Chihuahua 22
# categ_train_dir  ./process\train\n02085620-Chihuahua 108
# dir  ./images/n02085782-Japanese_spaniel 185
# categ_test_dir   ./process\test\n02085782-Japanese_spaniel 27
# categ_val_dir    ./process\validation\n02085782-Japanese_spaniel 27
# categ_train_dir  ./process\train\n02085782-Japanese_spaniel 131
# dir  ./images/n02085936-Maltese_dog 252
# categ_test_dir   ./process\test\n02085936-Maltese_dog 37
# categ_val_dir    ./process\validation\n02085936-Maltese_dog 37
# categ_train_dir  ./process\train\n02085936-Maltese_dog 178
# dir  ./images/n02086079-Pekinese 149
# categ_test_dir   ./process\test\n02086079-Pekinese 22
# categ_val_dir    ./process\validation\n02086079-Pekinese 22
# categ_train_dir  ./process\train\n02086079-Pekinese 105
# dir  ./images/n02086240-Shih-Tzu 214
# categ_test_dir   ./process\test\n02086240-Shih-Tzu 32
# categ_val_dir    ./process\validation\n02086240-Shih-Tzu 32
# categ_train_dir  ./process\train\n02086240-Shih-Tzu 150
# dir  ./images/n02086646-Blenheim_spaniel 188
# categ_test_dir   ./process\test\n02086646-Blenheim_spaniel 28
# categ_val_dir    ./process\validation\n02086646-Blenheim_spaniel 28
# categ_train_dir  ./process\train\n02086646-Blenheim_spaniel 132
# dir  ./images/n02086910-papillon 196
# categ_test_dir   ./process\test\n02086910-papillon 29
# categ_val_dir    ./process\validation\n02086910-papillon 29
# categ_train_dir  ./process\train\n02086910-papillon 138
# dir  ./images/n02087046-toy_terrier 172
# categ_test_dir   ./process\test\n02087046-toy_terrier 25
# categ_val_dir    ./process\validation\n02087046-toy_terrier 25
# categ_train_dir  ./process\train\n02087046-toy_terrier 122
# dir  ./images/n02087394-Rhodesian_ridgeback 172
# categ_test_dir   ./process\test\n02087394-Rhodesian_ridgeback 25
# categ_val_dir    ./process\validation\n02087394-Rhodesian_ridgeback 25
# categ_train_dir  ./process\train\n02087394-Rhodesian_ridgeback 122
# dir  ./images/n02088094-Afghan_hound 239
# categ_test_dir   ./process\test\n02088094-Afghan_hound 35
# categ_val_dir    ./process\validation\n02088094-Afghan_hound 35
# categ_train_dir  ./process\train\n02088094-Afghan_hound 169
# dir  ./images/n02088238-basset 175
# categ_test_dir   ./process\test\n02088238-basset 26
# categ_val_dir    ./process\validation\n02088238-basset 26
# categ_train_dir  ./process\train\n02088238-basset 123
# dir  ./images/n02088364-beagle 195
# categ_test_dir   ./process\test\n02088364-beagle 29
# categ_val_dir    ./process\validation\n02088364-beagle 29
# categ_train_dir  ./process\train\n02088364-beagle 137
# dir  ./images/n02088466-bloodhound 187
# categ_test_dir   ./process\test\n02088466-bloodhound 28
# categ_val_dir    ./process\validation\n02088466-bloodhound 28
# categ_train_dir  ./process\train\n02088466-bloodhound 131
# dir  ./images/n02088632-bluetick 171
# categ_test_dir   ./process\test\n02088632-bluetick 25
# categ_val_dir    ./process\validation\n02088632-bluetick 25
# categ_train_dir  ./process\train\n02088632-bluetick 121
# dir  ./images/n02089078-black-and-tan_coonhound 159
# categ_test_dir   ./process\test\n02089078-black-and-tan_coonhound 23
# categ_val_dir    ./process\validation\n02089078-black-and-tan_coonhound 23
# categ_train_dir  ./process\train\n02089078-black-and-tan_coonhound 113
# dir  ./images/n02089867-Walker_hound 153
# categ_test_dir   ./process\test\n02089867-Walker_hound 22
# categ_val_dir    ./process\validation\n02089867-Walker_hound 22
# categ_train_dir  ./process\train\n02089867-Walker_hound 109
# dir  ./images/n02089973-English_foxhound 157
# categ_test_dir   ./process\test\n02089973-English_foxhound 23
# categ_val_dir    ./process\validation\n02089973-English_foxhound 23
# categ_train_dir  ./process\train\n02089973-English_foxhound 111
# dir  ./images/n02090379-redbone 148
# categ_test_dir   ./process\test\n02090379-redbone 22
# categ_val_dir    ./process\validation\n02090379-redbone 22
# categ_train_dir  ./process\train\n02090379-redbone 104
# dir  ./images/n02090622-borzoi 151
# categ_test_dir   ./process\test\n02090622-borzoi 22
# categ_val_dir    ./process\validation\n02090622-borzoi 22
# categ_train_dir  ./process\train\n02090622-borzoi 107
# dir  ./images/n02090721-Irish_wolfhound 218
# categ_test_dir   ./process\test\n02090721-Irish_wolfhound 32
# categ_val_dir    ./process\validation\n02090721-Irish_wolfhound 32
# categ_train_dir  ./process\train\n02090721-Irish_wolfhound 154
# dir  ./images/n02091032-Italian_greyhound 182
# categ_test_dir   ./process\test\n02091032-Italian_greyhound 27
# categ_val_dir    ./process\validation\n02091032-Italian_greyhound 27
# categ_train_dir  ./process\train\n02091032-Italian_greyhound 128
# dir  ./images/n02091134-whippet 187
# categ_test_dir   ./process\test\n02091134-whippet 28
# categ_val_dir    ./process\validation\n02091134-whippet 28
# categ_train_dir  ./process\train\n02091134-whippet 131
# dir  ./images/n02091244-Ibizan_hound 188
# categ_test_dir   ./process\test\n02091244-Ibizan_hound 28
# categ_val_dir    ./process\validation\n02091244-Ibizan_hound 28
# categ_train_dir  ./process\train\n02091244-Ibizan_hound 132
# dir  ./images/n02091467-Norwegian_elkhound 196
# categ_test_dir   ./process\test\n02091467-Norwegian_elkhound 29
# categ_val_dir    ./process\validation\n02091467-Norwegian_elkhound 29
# categ_train_dir  ./process\train\n02091467-Norwegian_elkhound 138
# dir  ./images/n02091635-otterhound 151
# categ_test_dir   ./process\test\n02091635-otterhound 22
# categ_val_dir    ./process\validation\n02091635-otterhound 22
# categ_train_dir  ./process\train\n02091635-otterhound 107
# dir  ./images/n02091831-Saluki 200
# categ_test_dir   ./process\test\n02091831-Saluki 30
# categ_val_dir    ./process\validation\n02091831-Saluki 30
# categ_train_dir  ./process\train\n02091831-Saluki 140
# dir  ./images/n02092002-Scottish_deerhound 232
# categ_test_dir   ./process\test\n02092002-Scottish_deerhound 34
# categ_val_dir    ./process\validation\n02092002-Scottish_deerhound 34
# categ_train_dir  ./process\train\n02092002-Scottish_deerhound 164
# dir  ./images/n02092339-Weimaraner 160
# categ_test_dir   ./process\test\n02092339-Weimaraner 24
# categ_val_dir    ./process\validation\n02092339-Weimaraner 24
# categ_train_dir  ./process\train\n02092339-Weimaraner 112
# dir  ./images/n02093256-Staffordshire_bullterrier 155
# categ_test_dir   ./process\test\n02093256-Staffordshire_bullterrier 23
# categ_val_dir    ./process\validation\n02093256-Staffordshire_bullterrier 23
# categ_train_dir  ./process\train\n02093256-Staffordshire_bullterrier 109
# dir  ./images/n02093428-American_Staffordshire_terrier 164
# categ_test_dir   ./process\test\n02093428-American_Staffordshire_terrier 24
# categ_val_dir    ./process\validation\n02093428-American_Staffordshire_terrier 24
# categ_train_dir  ./process\train\n02093428-American_Staffordshire_terrier 116
# dir  ./images/n02093647-Bedlington_terrier 182
# categ_test_dir   ./process\test\n02093647-Bedlington_terrier 27
# categ_val_dir    ./process\validation\n02093647-Bedlington_terrier 27
# categ_train_dir  ./process\train\n02093647-Bedlington_terrier 128
# dir  ./images/n02093754-Border_terrier 172
# categ_test_dir   ./process\test\n02093754-Border_terrier 25
# categ_val_dir    ./process\validation\n02093754-Border_terrier 25
# categ_train_dir  ./process\train\n02093754-Border_terrier 122
# dir  ./images/n02093859-Kerry_blue_terrier 179
# categ_test_dir   ./process\test\n02093859-Kerry_blue_terrier 26
# categ_val_dir    ./process\validation\n02093859-Kerry_blue_terrier 26
# categ_train_dir  ./process\train\n02093859-Kerry_blue_terrier 127
# dir  ./images/n02093991-Irish_terrier 169
# categ_test_dir   ./process\test\n02093991-Irish_terrier 25
# categ_val_dir    ./process\validation\n02093991-Irish_terrier 25
# categ_train_dir  ./process\train\n02093991-Irish_terrier 119
# dir  ./images/n02094114-Norfolk_terrier 172
# categ_test_dir   ./process\test\n02094114-Norfolk_terrier 25
# categ_val_dir    ./process\validation\n02094114-Norfolk_terrier 25
# categ_train_dir  ./process\train\n02094114-Norfolk_terrier 122
# dir  ./images/n02094258-Norwich_terrier 185
# categ_test_dir   ./process\test\n02094258-Norwich_terrier 27
# categ_val_dir    ./process\validation\n02094258-Norwich_terrier 27
# categ_train_dir  ./process\train\n02094258-Norwich_terrier 131
# dir  ./images/n02094433-Yorkshire_terrier 164
# categ_test_dir   ./process\test\n02094433-Yorkshire_terrier 24
# categ_val_dir    ./process\validation\n02094433-Yorkshire_terrier 24
# categ_train_dir  ./process\train\n02094433-Yorkshire_terrier 116
# dir  ./images/n02095314-wire-haired_fox_terrier 157
# categ_test_dir   ./process\test\n02095314-wire-haired_fox_terrier 23
# categ_val_dir    ./process\validation\n02095314-wire-haired_fox_terrier 23
# categ_train_dir  ./process\train\n02095314-wire-haired_fox_terrier 111
# dir  ./images/n02095570-Lakeland_terrier 197
# categ_test_dir   ./process\test\n02095570-Lakeland_terrier 29
# categ_val_dir    ./process\validation\n02095570-Lakeland_terrier 29
# categ_train_dir  ./process\train\n02095570-Lakeland_terrier 139
# dir  ./images/n02095889-Sealyham_terrier 202
# categ_test_dir   ./process\test\n02095889-Sealyham_terrier 30
# categ_val_dir    ./process\validation\n02095889-Sealyham_terrier 30
# categ_train_dir  ./process\train\n02095889-Sealyham_terrier 142
# dir  ./images/n02096051-Airedale 202
# categ_test_dir   ./process\test\n02096051-Airedale 30
# categ_val_dir    ./process\validation\n02096051-Airedale 30
# categ_train_dir  ./process\train\n02096051-Airedale 142
# dir  ./images/n02096177-cairn 197
# categ_test_dir   ./process\test\n02096177-cairn 29
# categ_val_dir    ./process\validation\n02096177-cairn 29
# categ_train_dir  ./process\train\n02096177-cairn 139
# dir  ./images/n02096294-Australian_terrier 196
# categ_test_dir   ./process\test\n02096294-Australian_terrier 29
# categ_val_dir    ./process\validation\n02096294-Australian_terrier 29
# categ_train_dir  ./process\train\n02096294-Australian_terrier 138
# dir  ./images/n02096437-Dandie_Dinmont 180
# categ_test_dir   ./process\test\n02096437-Dandie_Dinmont 27
# categ_val_dir    ./process\validation\n02096437-Dandie_Dinmont 27
# categ_train_dir  ./process\train\n02096437-Dandie_Dinmont 126
# dir  ./images/n02096585-Boston_bull 182
# categ_test_dir   ./process\test\n02096585-Boston_bull 27
# categ_val_dir    ./process\validation\n02096585-Boston_bull 27
# categ_train_dir  ./process\train\n02096585-Boston_bull 128
# dir  ./images/n02097047-miniature_schnauzer 154
# categ_test_dir   ./process\test\n02097047-miniature_schnauzer 23
# categ_val_dir    ./process\validation\n02097047-miniature_schnauzer 23
# categ_train_dir  ./process\train\n02097047-miniature_schnauzer 108
# dir  ./images/n02097130-giant_schnauzer 157
# categ_test_dir   ./process\test\n02097130-giant_schnauzer 23
# categ_val_dir    ./process\validation\n02097130-giant_schnauzer 23
# categ_train_dir  ./process\train\n02097130-giant_schnauzer 111
# dir  ./images/n02097209-standard_schnauzer 155
# categ_test_dir   ./process\test\n02097209-standard_schnauzer 23
# categ_val_dir    ./process\validation\n02097209-standard_schnauzer 23
# categ_train_dir  ./process\train\n02097209-standard_schnauzer 109
# dir  ./images/n02097298-Scotch_terrier 158
# categ_test_dir   ./process\test\n02097298-Scotch_terrier 23
# categ_val_dir    ./process\validation\n02097298-Scotch_terrier 23
# categ_train_dir  ./process\train\n02097298-Scotch_terrier 112
# dir  ./images/n02097474-Tibetan_terrier 206
# categ_test_dir   ./process\test\n02097474-Tibetan_terrier 30
# categ_val_dir    ./process\validation\n02097474-Tibetan_terrier 30
# categ_train_dir  ./process\train\n02097474-Tibetan_terrier 146
# dir  ./images/n02097658-silky_terrier 183
# categ_test_dir   ./process\test\n02097658-silky_terrier 27
# categ_val_dir    ./process\validation\n02097658-silky_terrier 27
# categ_train_dir  ./process\train\n02097658-silky_terrier 129
# dir  ./images/n02098105-soft-coated_wheaten_terrier 156
# categ_test_dir   ./process\test\n02098105-soft-coated_wheaten_terrier 23
# categ_val_dir    ./process\validation\n02098105-soft-coated_wheaten_terrier 23
# categ_train_dir  ./process\train\n02098105-soft-coated_wheaten_terrier 110
# dir  ./images/n02098286-West_Highland_white_terrier 169
# categ_test_dir   ./process\test\n02098286-West_Highland_white_terrier 25
# categ_val_dir    ./process\validation\n02098286-West_Highland_white_terrier 25
# categ_train_dir  ./process\train\n02098286-West_Highland_white_terrier 119
# dir  ./images/n02098413-Lhasa 186
# categ_test_dir   ./process\test\n02098413-Lhasa 27
# categ_val_dir    ./process\validation\n02098413-Lhasa 27
# categ_train_dir  ./process\train\n02098413-Lhasa 132
# dir  ./images/n02099267-flat-coated_retriever 152
# categ_test_dir   ./process\test\n02099267-flat-coated_retriever 22
# categ_val_dir    ./process\validation\n02099267-flat-coated_retriever 22
# categ_train_dir  ./process\train\n02099267-flat-coated_retriever 108
# dir  ./images/n02099429-curly-coated_retriever 151
# categ_test_dir   ./process\test\n02099429-curly-coated_retriever 22
# categ_val_dir    ./process\validation\n02099429-curly-coated_retriever 22
# categ_train_dir  ./process\train\n02099429-curly-coated_retriever 107
# dir  ./images/n02099601-golden_retriever 150
# categ_test_dir   ./process\test\n02099601-golden_retriever 22
# categ_val_dir    ./process\validation\n02099601-golden_retriever 22
# categ_train_dir  ./process\train\n02099601-golden_retriever 106
# dir  ./images/n02099712-Labrador_retriever 171
# categ_test_dir   ./process\test\n02099712-Labrador_retriever 25
# categ_val_dir    ./process\validation\n02099712-Labrador_retriever 25
# categ_train_dir  ./process\train\n02099712-Labrador_retriever 121
# dir  ./images/n02099849-Chesapeake_Bay_retriever 167
# categ_test_dir   ./process\test\n02099849-Chesapeake_Bay_retriever 25
# categ_val_dir    ./process\validation\n02099849-Chesapeake_Bay_retriever 25
# categ_train_dir  ./process\train\n02099849-Chesapeake_Bay_retriever 117
# dir  ./images/n02100236-German_short-haired_pointer 152
# categ_test_dir   ./process\test\n02100236-German_short-haired_pointer 22
# categ_val_dir    ./process\validation\n02100236-German_short-haired_pointer 22
# categ_train_dir  ./process\train\n02100236-German_short-haired_pointer 108
# dir  ./images/n02100583-vizsla 154
# categ_test_dir   ./process\test\n02100583-vizsla 23
# categ_val_dir    ./process\validation\n02100583-vizsla 23
# categ_train_dir  ./process\train\n02100583-vizsla 108
# dir  ./images/n02100735-English_setter 161
# categ_test_dir   ./process\test\n02100735-English_setter 24
# categ_val_dir    ./process\validation\n02100735-English_setter 24
# categ_train_dir  ./process\train\n02100735-English_setter 113
# dir  ./images/n02100877-Irish_setter 155
# categ_test_dir   ./process\test\n02100877-Irish_setter 23
# categ_val_dir    ./process\validation\n02100877-Irish_setter 23
# categ_train_dir  ./process\train\n02100877-Irish_setter 109
# dir  ./images/n02101006-Gordon_setter 153
# categ_test_dir   ./process\test\n02101006-Gordon_setter 22
# categ_val_dir    ./process\validation\n02101006-Gordon_setter 22
# categ_train_dir  ./process\train\n02101006-Gordon_setter 109
# dir  ./images/n02101388-Brittany_spaniel 152
# categ_test_dir   ./process\test\n02101388-Brittany_spaniel 22
# categ_val_dir    ./process\validation\n02101388-Brittany_spaniel 22
# categ_train_dir  ./process\train\n02101388-Brittany_spaniel 108
# dir  ./images/n02101556-clumber 150
# categ_test_dir   ./process\test\n02101556-clumber 22
# categ_val_dir    ./process\validation\n02101556-clumber 22
# categ_train_dir  ./process\train\n02101556-clumber 106
# dir  ./images/n02102040-English_springer 159
# categ_test_dir   ./process\test\n02102040-English_springer 23
# categ_val_dir    ./process\validation\n02102040-English_springer 23
# categ_train_dir  ./process\train\n02102040-English_springer 113
# dir  ./images/n02102177-Welsh_springer_spaniel 150
# categ_test_dir   ./process\test\n02102177-Welsh_springer_spaniel 22
# categ_val_dir    ./process\validation\n02102177-Welsh_springer_spaniel 22
# categ_train_dir  ./process\train\n02102177-Welsh_springer_spaniel 106
# dir  ./images/n02102318-cocker_spaniel 159
# categ_test_dir   ./process\test\n02102318-cocker_spaniel 23
# categ_val_dir    ./process\validation\n02102318-cocker_spaniel 23
# categ_train_dir  ./process\train\n02102318-cocker_spaniel 113
# dir  ./images/n02102480-Sussex_spaniel 151
# categ_test_dir   ./process\test\n02102480-Sussex_spaniel 22
# categ_val_dir    ./process\validation\n02102480-Sussex_spaniel 22
# categ_train_dir  ./process\train\n02102480-Sussex_spaniel 107
# dir  ./images/n02102973-Irish_water_spaniel 150
# categ_test_dir   ./process\test\n02102973-Irish_water_spaniel 22
# categ_val_dir    ./process\validation\n02102973-Irish_water_spaniel 22
# categ_train_dir  ./process\train\n02102973-Irish_water_spaniel 106
# dir  ./images/n02104029-kuvasz 150
# categ_test_dir   ./process\test\n02104029-kuvasz 22
# categ_val_dir    ./process\validation\n02104029-kuvasz 22
# categ_train_dir  ./process\train\n02104029-kuvasz 106
# dir  ./images/n02104365-schipperke 154
# categ_test_dir   ./process\test\n02104365-schipperke 23
# categ_val_dir    ./process\validation\n02104365-schipperke 23
# categ_train_dir  ./process\train\n02104365-schipperke 108
# dir  ./images/n02105056-groenendael 150
# categ_test_dir   ./process\test\n02105056-groenendael 22
# categ_val_dir    ./process\validation\n02105056-groenendael 22
# categ_train_dir  ./process\train\n02105056-groenendael 106
# dir  ./images/n02105162-malinois 150
# categ_test_dir   ./process\test\n02105162-malinois 22
# categ_val_dir    ./process\validation\n02105162-malinois 22
# categ_train_dir  ./process\train\n02105162-malinois 106
# dir  ./images/n02105251-briard 152
# categ_test_dir   ./process\test\n02105251-briard 22
# categ_val_dir    ./process\validation\n02105251-briard 22
# categ_train_dir  ./process\train\n02105251-briard 108
# dir  ./images/n02105412-kelpie 153
# categ_test_dir   ./process\test\n02105412-kelpie 22
# categ_val_dir    ./process\validation\n02105412-kelpie 22
# categ_train_dir  ./process\train\n02105412-kelpie 109
# dir  ./images/n02105505-komondor 154
# categ_test_dir   ./process\test\n02105505-komondor 23
# categ_val_dir    ./process\validation\n02105505-komondor 23
# categ_train_dir  ./process\train\n02105505-komondor 108
# dir  ./images/n02105641-Old_English_sheepdog 169
# categ_test_dir   ./process\test\n02105641-Old_English_sheepdog 25
# categ_val_dir    ./process\validation\n02105641-Old_English_sheepdog 25
# categ_train_dir  ./process\train\n02105641-Old_English_sheepdog 119
# dir  ./images/n02105855-Shetland_sheepdog 157
# categ_test_dir   ./process\test\n02105855-Shetland_sheepdog 23
# categ_val_dir    ./process\validation\n02105855-Shetland_sheepdog 23
# categ_train_dir  ./process\train\n02105855-Shetland_sheepdog 111
# dir  ./images/n02106030-collie 153
# categ_test_dir   ./process\test\n02106030-collie 22
# categ_val_dir    ./process\validation\n02106030-collie 22
# categ_train_dir  ./process\train\n02106030-collie 109
# dir  ./images/n02106166-Border_collie 150
# categ_test_dir   ./process\test\n02106166-Border_collie 22
# categ_val_dir    ./process\validation\n02106166-Border_collie 22
# categ_train_dir  ./process\train\n02106166-Border_collie 106
# dir  ./images/n02106382-Bouvier_des_Flandres 150
# categ_test_dir   ./process\test\n02106382-Bouvier_des_Flandres 22
# categ_val_dir    ./process\validation\n02106382-Bouvier_des_Flandres 22
# categ_train_dir  ./process\train\n02106382-Bouvier_des_Flandres 106
# dir  ./images/n02106550-Rottweiler 152
# categ_test_dir   ./process\test\n02106550-Rottweiler 22
# categ_val_dir    ./process\validation\n02106550-Rottweiler 22
# categ_train_dir  ./process\train\n02106550-Rottweiler 108
# dir  ./images/n02106662-German_shepherd 152
# categ_test_dir   ./process\test\n02106662-German_shepherd 22
# categ_val_dir    ./process\validation\n02106662-German_shepherd 22
# categ_train_dir  ./process\train\n02106662-German_shepherd 108
# dir  ./images/n02107142-Doberman 150
# categ_test_dir   ./process\test\n02107142-Doberman 22
# categ_val_dir    ./process\validation\n02107142-Doberman 22
# categ_train_dir  ./process\train\n02107142-Doberman 106
# dir  ./images/n02107312-miniature_pinscher 184
# categ_test_dir   ./process\test\n02107312-miniature_pinscher 27
# categ_val_dir    ./process\validation\n02107312-miniature_pinscher 27
# categ_train_dir  ./process\train\n02107312-miniature_pinscher 130
# dir  ./images/n02107574-Greater_Swiss_Mountain_dog 168
# categ_test_dir   ./process\test\n02107574-Greater_Swiss_Mountain_dog 25
# categ_val_dir    ./process\validation\n02107574-Greater_Swiss_Mountain_dog 25
# categ_train_dir  ./process\train\n02107574-Greater_Swiss_Mountain_dog 118
# dir  ./images/n02107683-Bernese_mountain_dog 218
# categ_test_dir   ./process\test\n02107683-Bernese_mountain_dog 32
# categ_val_dir    ./process\validation\n02107683-Bernese_mountain_dog 32
# categ_train_dir  ./process\train\n02107683-Bernese_mountain_dog 154
# dir  ./images/n02107908-Appenzeller 151
# categ_test_dir   ./process\test\n02107908-Appenzeller 22
# categ_val_dir    ./process\validation\n02107908-Appenzeller 22
# categ_train_dir  ./process\train\n02107908-Appenzeller 107
# dir  ./images/n02108000-EntleBucher 202
# categ_test_dir   ./process\test\n02108000-EntleBucher 30
# categ_val_dir    ./process\validation\n02108000-EntleBucher 30
# categ_train_dir  ./process\train\n02108000-EntleBucher 142
# dir  ./images/n02108089-boxer 151
# categ_test_dir   ./process\test\n02108089-boxer 22
# categ_val_dir    ./process\validation\n02108089-boxer 22
# categ_train_dir  ./process\train\n02108089-boxer 107
# dir  ./images/n02108422-bull_mastiff 156
# categ_test_dir   ./process\test\n02108422-bull_mastiff 23
# categ_val_dir    ./process\validation\n02108422-bull_mastiff 23
# categ_train_dir  ./process\train\n02108422-bull_mastiff 110
# dir  ./images/n02108551-Tibetan_mastiff 152
# categ_test_dir   ./process\test\n02108551-Tibetan_mastiff 22
# categ_val_dir    ./process\validation\n02108551-Tibetan_mastiff 22
# categ_train_dir  ./process\train\n02108551-Tibetan_mastiff 108
# dir  ./images/n02108915-French_bulldog 159
# categ_test_dir   ./process\test\n02108915-French_bulldog 23
# categ_val_dir    ./process\validation\n02108915-French_bulldog 23
# categ_train_dir  ./process\train\n02108915-French_bulldog 113
# dir  ./images/n02109047-Great_Dane 156
# categ_test_dir   ./process\test\n02109047-Great_Dane 23
# categ_val_dir    ./process\validation\n02109047-Great_Dane 23
# categ_train_dir  ./process\train\n02109047-Great_Dane 110
# dir  ./images/n02109525-Saint_Bernard 170
# categ_test_dir   ./process\test\n02109525-Saint_Bernard 25
# categ_val_dir    ./process\validation\n02109525-Saint_Bernard 25
# categ_train_dir  ./process\train\n02109525-Saint_Bernard 120
# dir  ./images/n02109961-Eskimo_dog 150
# categ_test_dir   ./process\test\n02109961-Eskimo_dog 22
# categ_val_dir    ./process\validation\n02109961-Eskimo_dog 22
# categ_train_dir  ./process\train\n02109961-Eskimo_dog 106
# dir  ./images/n02110063-malamute 178
# categ_test_dir   ./process\test\n02110063-malamute 26
# categ_val_dir    ./process\validation\n02110063-malamute 26
# categ_train_dir  ./process\train\n02110063-malamute 126
# dir  ./images/n02110185-Siberian_husky 192
# categ_test_dir   ./process\test\n02110185-Siberian_husky 28
# categ_val_dir    ./process\validation\n02110185-Siberian_husky 28
# categ_train_dir  ./process\train\n02110185-Siberian_husky 136
# dir  ./images/n02110627-affenpinscher 150
# categ_test_dir   ./process\test\n02110627-affenpinscher 22
# categ_val_dir    ./process\validation\n02110627-affenpinscher 22
# categ_train_dir  ./process\train\n02110627-affenpinscher 106
# dir  ./images/n02110806-basenji 209
# categ_test_dir   ./process\test\n02110806-basenji 31
# categ_val_dir    ./process\validation\n02110806-basenji 31
# categ_train_dir  ./process\train\n02110806-basenji 147
# dir  ./images/n02110958-pug 200
# categ_test_dir   ./process\test\n02110958-pug 30
# categ_val_dir    ./process\validation\n02110958-pug 30
# categ_train_dir  ./process\train\n02110958-pug 140
# dir  ./images/n02111129-Leonberg 210
# categ_test_dir   ./process\test\n02111129-Leonberg 31
# categ_val_dir    ./process\validation\n02111129-Leonberg 31
# categ_train_dir  ./process\train\n02111129-Leonberg 148
# dir  ./images/n02111277-Newfoundland 195
# categ_test_dir   ./process\test\n02111277-Newfoundland 29
# categ_val_dir    ./process\validation\n02111277-Newfoundland 29
# categ_train_dir  ./process\train\n02111277-Newfoundland 137
# dir  ./images/n02111500-Great_Pyrenees 213
# categ_test_dir   ./process\test\n02111500-Great_Pyrenees 31
# categ_val_dir    ./process\validation\n02111500-Great_Pyrenees 31
# categ_train_dir  ./process\train\n02111500-Great_Pyrenees 151
# dir  ./images/n02111889-Samoyed 218
# categ_test_dir   ./process\test\n02111889-Samoyed 32
# categ_val_dir    ./process\validation\n02111889-Samoyed 32
# categ_train_dir  ./process\train\n02111889-Samoyed 154
# dir  ./images/n02112018-Pomeranian 219
# categ_test_dir   ./process\test\n02112018-Pomeranian 32
# categ_val_dir    ./process\validation\n02112018-Pomeranian 32
# categ_train_dir  ./process\train\n02112018-Pomeranian 155
# dir  ./images/n02112137-chow 196
# categ_test_dir   ./process\test\n02112137-chow 29
# categ_val_dir    ./process\validation\n02112137-chow 29
# categ_train_dir  ./process\train\n02112137-chow 138
# dir  ./images/n02112350-keeshond 158
# categ_test_dir   ./process\test\n02112350-keeshond 23
# categ_val_dir    ./process\validation\n02112350-keeshond 23
# categ_train_dir  ./process\train\n02112350-keeshond 112
# dir  ./images/n02112706-Brabancon_griffon 153
# categ_test_dir   ./process\test\n02112706-Brabancon_griffon 22
# categ_val_dir    ./process\validation\n02112706-Brabancon_griffon 22
# categ_train_dir  ./process\train\n02112706-Brabancon_griffon 109
# dir  ./images/n02113023-Pembroke 181
# categ_test_dir   ./process\test\n02113023-Pembroke 27
# categ_val_dir    ./process\validation\n02113023-Pembroke 27
# categ_train_dir  ./process\train\n02113023-Pembroke 127
# dir  ./images/n02113186-Cardigan 155
# categ_test_dir   ./process\test\n02113186-Cardigan 23
# categ_val_dir    ./process\validation\n02113186-Cardigan 23
# categ_train_dir  ./process\train\n02113186-Cardigan 109
# dir  ./images/n02113624-toy_poodle 151
# categ_test_dir   ./process\test\n02113624-toy_poodle 22
# categ_val_dir    ./process\validation\n02113624-toy_poodle 22
# categ_train_dir  ./process\train\n02113624-toy_poodle 107
# dir  ./images/n02113712-miniature_poodle 155
# categ_test_dir   ./process\test\n02113712-miniature_poodle 23
# categ_val_dir    ./process\validation\n02113712-miniature_poodle 23
# categ_train_dir  ./process\train\n02113712-miniature_poodle 109
# dir  ./images/n02113799-standard_poodle 159
# categ_test_dir   ./process\test\n02113799-standard_poodle 23
# categ_val_dir    ./process\validation\n02113799-standard_poodle 23
# categ_train_dir  ./process\train\n02113799-standard_poodle 113
# dir  ./images/n02113978-Mexican_hairless 155
# categ_test_dir   ./process\test\n02113978-Mexican_hairless 23
# categ_val_dir    ./process\validation\n02113978-Mexican_hairless 23
# categ_train_dir  ./process\train\n02113978-Mexican_hairless 109
# dir  ./images/n02115641-dingo 156
# categ_test_dir   ./process\test\n02115641-dingo 23
# categ_val_dir    ./process\validation\n02115641-dingo 23
# categ_train_dir  ./process\train\n02115641-dingo 110
# dir  ./images/n02115913-dhole 150
# categ_test_dir   ./process\test\n02115913-dhole 22
# categ_val_dir    ./process\validation\n02115913-dhole 22
# categ_train_dir  ./process\train\n02115913-dhole 106
# dir  ./images/n02116738-African_hunting_dog 169
# categ_test_dir   ./process\test\n02116738-African_hunting_dog 25
# categ_val_dir    ./process\validation\n02116738-African_hunting_dog 25
# categ_train_dir  ./process\train\n02116738-African_hunting_dog 119
